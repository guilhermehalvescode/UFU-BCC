# %% [markdown]
# ## Rolando dados
# ---

# %%
import numpy as np

num_lados = 6
num_rolagens = 100

# Simula rolagens
vetor_rolagens = np.random.randint(1, num_lados + 1, size=num_rolagens)
# Calcula media
print(vetor_rolagens)
media = np.mean(vetor_rolagens)

print("Media de 100 rolagens de dados:", media)
# Out:
# [4 5 6 5 1 1 3 4 1 3 4 5 6 3 3 4 4 6 5 4 5 4 2 2 3 2 1 4 6 1 4 4 1 5 6 1 3
#  3 1 1 4 5 6 5 3 3 3 6 2 2 5 4 6 5 1 4 3 4 6 1 1 5 1 4 2 5 5 6 5 2 6 5 3 4
#  2 2 1 2 6 3 4 2 5 4 5 3 6 2 4 5 6 1 5 2 4 3 4 2 3 2]
# Media de 100 rolagens de dados: 3.56

# %% [markdown]
# ## Lançamentos de moedas

# %%
import numpy as np
import matplotlib.pyplot as plt

# Initialize starting position and list of positions
position = 0
positions = [0]

# Generate 50 random steps of size 1 and update position
for i in range(200):
    step = np.random.choice([-1, 1])
    position += step
    positions.append(position)

# Plot the random walk
plt.plot(positions)
plt.title("Random Walk (50 Steps of Size 1)")
plt.xlabel("Step Number")
plt.ylabel("Position")
plt.show()

# %% [markdown]
# ## Lançamento de dados com soma

# %%
import numpy as np
import matplotlib.pyplot as plt

results = []

# Preenche vetor com rolagens de dados
for i in range(1000):
    results.append(np.random.randint(1, 7) + np.random.randint(1, 7) + np.random.randint(1, 7))

print(results)

# Plotar histograma
plt.hist(results, bins=range(1, 20), align='left', rwidth=0.8, edgecolor='black')
plt.xlabel('Result of 2d6 Roll')
plt.ylabel('Frequency')
plt.title('Histogram of 2d6 Rolls')
plt.xticks(range(1, 20))
plt.grid(axis='y', alpha=0.75)
plt.show()
# Out:
# [12, 8, 14, 9, 12, 8, 7, 9, 9, 15, 7, 7, 15, 9, 14, 12, 11, 9, 13, 6, 12, 15, 10, 11, 14, 11, 8, 12, 16, 12, 10, 6, 15, 9, 7, 12, 13, 11, 10, 10, 11, 6, 10, 12, 10, 10, 12, 11, 10, 7, 11, 12, 13, 9, 8, 4, 13, 7, 9, 8, 8, 14, 10, 14, 9, 10, 13, 8, 12, 7, 12, 18, 7, 11, 11, 13, 11, 13, 4, 10, 16, 12, 12, 8, 8, 12, 10, 6, 11, 10, 12, 11, 12, 9, 9, 12, 6, 4, 7, 14, 11, 13, 7, 12, 10, 7, 7, 11, 8, 13, 8, 11, 14, 8, 10, 13, 14, 10, 9, 10, 10, 9, 14, 10, 14, 7, 9, 11, 11, 15, 10, 8, 13, 13, 16, 10, 7, 15, 7, 8, 8, 15, 14, 18, 6, 12, 8, 8, 13, 13, 13, 9, 10, 7, 14, 7, 14, 7, 10, 13, 15, 9, 5, 10, 10, 12, 15, 12, 11, 7, 9, 10, 8, 
 9, 8, 4, 8, 8, 10, 14, 13, 11, 8, 9, 13, 11, 10, 13, 8, 17, 12, 12, 15, 12, 12, 13, 17, 4, 4, 7, 4, 10, 12, 14, 11, 12, 11, 8, 9, 14, 11, 11, 13, 10, 5, 15, 9, 13, 11, 14, 16, 14, 13, 7, 10, 17, 9, 11, 13, 5, 11, 14, 13, 9, 10, 10, 14, 14, 18, 16, 7, 13, 12, 13, 3, 9, 9, 10, 8, 15, 9, 9, 12, 8, 10, 17, 11, 12, 13, 11, 14, 11, 8, 10, 12, 9, 11, 8, 12, 11, 11, 10, 10, 12, 14, 16, 8, 7, 11, 9, 9, 15, 15, 11, 15, 10, 10, 7, 8, 9, 9, 7, 9, 5, 8, 9, 10, 11, 13, 10, 9, 14, 12, 10, 10, 14, 14, 12, 8, 7, 16, 8, 12, 9, 14, 7, 16, 10, 5, 15, 14, 14, 10, 14, 7, 10, 16, 12, 10, 9, 11, 11, 11, 9, 13, 11, 10, 12, 17, 8, 13, 10, 15, 4, 6, 12, 11, 9, 7, 17, 17, 11, 7, 4, 8, 13, 7, 11, 7, 7, 10, 11, 15, 9, 12, 10, 9, 11, 14, 9, 12, 10, 9, 10, 16, 6, 10, 11, 12, 7, 9, 12, 9, 11, 6, 8, 4, 14, 10, 8, 8, 8, 8, 8, 12, 10, 12, 13, 6, 7, 13, 13, 12, 16, 15, 10, 6, 8, 13, 12, 9, 5, 14, 10, 5, 9, 4, 14, 10, 12, 4, 11, 8, 10, 17, 15, 9, 14, 12, 9, 7, 9, 7, 4, 9, 15, 13, 10, 11, 13, 17, 9, 13, 11, 12, 11, 8, 8, 12, 12, 7, 14, 9, 12, 13, 9, 8, 10, 9, 6, 12, 9, 11, 9, 12, 15, 10, 10, 12, 10, 7, 16, 12, 12, 10, 9, 8, 10, 10, 13, 10, 12, 10, 12, 9, 15, 8, 16, 9, 13, 14, 7, 10, 8, 10, 7, 11, 9, 10, 12, 7, 11, 5, 11, 15, 12, 15, 9, 7, 9, 8, 14, 8, 11, 10, 11, 12, 11, 8, 4, 8, 3, 6, 15, 15, 11, 9, 6, 6, 9, 12, 13, 11, 6, 7]

# %% [markdown]
# ##

# %%
import numpy as np
import matplotlib.pyplot as plt

results = []

for i in range(100000):
    
    if np.random.rand() < 0.5:
        
        if np.random.rand() < 2/9:
            # peguei branca heads
            results.append('BH')
        else:
            # peguei preta heads
            results.append('PH')
    else:
        if np.random.rand() < 5/11:
            # peguei branca tails
            results.append('BT')
        else:
            # peguei preta tails
            results.append('PT')
      
a, counts = np.unique(results, return_counts=True)
print(a, counts)

plt.bar(a, counts)

print(counts[0]/(counts[0] + counts[1]))
# Out:
# ['BH' 'BT' 'PH' 'PT'] [11193 22731 38865 27211]
# 0.32994340290060137
